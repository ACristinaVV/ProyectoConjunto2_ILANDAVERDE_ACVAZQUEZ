# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Ivette Landaverde Mercado y Ana Cristina Vazquez Vargas
#
# **Fecha:** 10 de febrero del 2021.
#
# **Expediente** : 722626 Y 721215.
# **Profesor:** Oscar David Jaramillo Zuluaga.
# **Repositorio:** https://github.com/ACristinaVV/ProyectoConjunto2_ILANDAVERDE_ACVAZQUEZ
# # Tarea 2: Clase 4

# %%
#Librerías:
import numpy as np
import matplotlib.pyplot as plt
from functools import reduce
from collections import Counter
from collections import deque
import pandas as pd

# %% [markdown]
# ### Los procedimientos que se presentan a lo largo de la tarea son los vistos en la Clase 4 Optimización de programación.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Respuesta Ivette

# %%
orders = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95], 
           ["98762", "Programming Python, Mark Lutz", 5, 56.80], 
           ["77226", "Head First Python, Paul Barry", 3,32.95],
           ["88112", "Einführung in Python3, Bernd Klein", 3, 24.99]]

# %%
z = list(map(lambda x: (x[0], x[2]*x[3] if x[2]*x[3] >= 100 else x[2]*x[3]+10 ), orders))
#La orden y precios totales son:
z
# Out:
# [('34587', 163.8),
#  ('98762', 284.0),
#  ('77226', 108.85000000000001),
#  ('88112', 84.97)]

# %% [markdown]
# ### Respuesta Cristina

# %%
orders = [4,5,3,3]
price = [40.95,56.80,32.95,24.99]

orders = [4,5,3,3]
price = [40.95,56.80,32.95,24.99]

total = list(map(lambda i,j: i*j, orders, price))

precios = list(map(lambda x: x+10 if x<100 else x,total)) 
 
solucion = [["34587", precios[0]],
          ["98762",precios[1]],
          ["77226",precios[2]],
          ["88112",precios[3]]]
solucion
# Out:
# [['34587', 163.8],
#  ['98762', 284.0],
#  ['77226', 108.85000000000001],
#  ['88112', 84.97]]

# %% [markdown]
# 2. La misma librería, pero esta vez trabajamos en una lista diferente. Las sublistas de nuestras listas se ven así:
# [número de orden, (número de artículo, cantidad, precio por unidad), ... (número de artículo, cantidad, precio por unidad)]
#
# `orders = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)],
# 	       [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
# 	       [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
#            [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]`
#
# Escriba un programa que devuelva una lista de dos tuplas que tengan la información de (número de pedido, cantidad total de pedido). Utilice la función `Reduce`. Recuerde el precio del pedido del producto debe aumentarse en 10€ si el valor de la orden es inferior a 100,00 €.

# %% [markdown]
# ### Respuesta Ivette

# %%
orders = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)], 
          [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
          [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
          [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]
m1 = list(map(lambda x: (x[0], reduce(lambda x,y: x+y, list(map(lambda y:y[1]*y[2] if y[1]*y[2]>100 else y[1]*y[2]+10, x[1:])))),orders))
m1
# Out:
# [(1, 688.3299999999999),
#  (2, 504.46000000000004),
#  (3, 374.79999999999995),
#  (4, 502.57)]

# %% [markdown]
# ### Respuesta Cristina

# %%
orders2 = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)], 
          [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
          [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
          [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]

resultado = list(map(lambda x: (x[0], reduce(lambda i,j: i+j,
                                            list(map(lambda y:y[1]*y[2] if y[1]*y[2]>100 else y[1]*y[2]+10,x[1:])))),orders2))
resultado
# Out:
# [(1, 688.3299999999999),
#  (2, 504.46000000000004),
#  (3, 374.79999999999995),
#  (4, 502.57)]

# %% [markdown]
# 3. Resolver los anteriores ejercicios usando pandas (DataFrame)

# %% [markdown]
# ### Respuesta Ivette

# %%
#ejercicios 1:

orders = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95], 
           ["98762", "Programming Python, Mark Lutz", 5, 56.80], 
           ["77226", "Head First Python, Paul Barry", 3,32.95],
           ["88112", "Einführung in Python3, Bernd Klein", 3, 24.99]]


df = pd.DataFrame(orders, columns = ["No. order", "name", "Quantity","Price"])
df["Q*P"]=df["Quantity"]*df["Price"]
df["Final_price"]=df["Q*P"].apply(lambda x: x if x >= 100 else x+10)
df.drop(["name","Quantity","Price","Q*P"], axis=1).set_index("No. order")
# Out:
#            Final_price
# No. order
# 34587           163.80
# 98762           284.00
# 77226           108.85
# 88112            84.97

# %%
#Ejercicio 2:
orders = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)], 
          [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
          [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
          [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]

df2 = pd.DataFrame(orders, columns = ["Número", "Orden A", "Orden B","Orden C"])
df2.replace((None,None,None), np.zeros((3,), dtype = "i,i,i"),inplace=True)

df2["FA"]= df2["Orden A"].apply(lambda x: (x[1]*x[2]if x[1]*x[2] >= 100 else x[1]*x[2]+10) ,orders)
df2["FB"]= df2["Orden B"].apply(lambda x: (x[1]*x[2]if x[1]*x[2] >= 100 else x[1]*x[2]+10),orders)
df2["FC"]= df2["Orden C"].apply(lambda x: (x[1]*x[2]) ,orders)
df2["Final"] = df2["FA"]+df2["FB"]+df2["FC"] 
df2
df2.drop(["Orden A","Orden B","Orden C","FA","FB","FC"], axis=1).set_index("Número")
# Out:
#          Final
# Número
# 1       688.33
# 2       504.46
# 3       374.80
# 4       502.57

# %% [markdown]
# ### Respuesta Cristy

# %%
#Ejercicio 1 con Pandas
orders1 = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95], 
           ["98762", "Programming Python, Mark Lutz", 5, 56.80], 
           ["77226", "Head First Python, Paul Barry", 3,32.95],
           ["88112", "Einführung in Python3, Bernd Klein", 3, 24.99]]
 
problema1 = pd.DataFrame(orders1)
total1 = pd.DataFrame({'Codigos':problema1[0], 'Total': (problema1[2]*problema1[3]).apply(lambda x: x+10 if x <= 100 else x) })
total1
# Out:
#   Codigos   Total
# 0   34587  163.80
# 1   98762  284.00
# 2   77226  108.85
# 3   88112   84.97

# %%
#Ejercicio 2 con Pandas
orders2 = [[1, "5464", 4, 9.99, "8274",18,12.99, "9744", 9, 44.95], 
          [2, "5464", 9, 9.99, "9744", 9, 44.95, 0, 0 ,0],
          [3, "5464", 9, 9.99, "88112", 11, 24.99, 0 , 0 , 0],
          [4, "8732", 7, 11.99,"7733",11,18.99, "88112", 5, 39.95] ]
A = pd.DataFrame(orders2)
total2 = pd.DataFrame({'Libreria':A[0], 'Total': (A[2]*A[3]).apply(lambda x: x+10 if 0 < x <= 100 else x) + 
                       (A[5]*A[6]).apply(lambda x: x+10 if 0 < x <= 100 else x) +
                      (A[8]*A[9]).apply(lambda x: x+10 if 0 < x <= 100 else x)})
total2
# Out:
#    Libreria   Total
# 0         1  688.33
# 1         2  504.46
# 2         3  374.80
# 3         4  502.57

# %% [markdown]
# 4. Use filter to eliminate all words that are shorter than 4 letters from a list of words
# `list='the notion of a lambda function goes all the way back to the origin of computer science'`

# %% [markdown]
# ### Respuesta Ivette

# %%
words="the notion of a lambda function goes all the way back to the origin of computer science"
respuesta = list(filter(lambda x: (len(x)>=4), words.split()))
print("las palabras que tienen 4 o más letras son:",respuesta)
# Out:
# las palabras que tienen 4 o más letras son: ['notion', 'lambda', 'function', 'goes', 'back', 'origin', 'computer', 'science']

# %% [markdown]
# ### Respuesta Cristy

# %%
palabras =['the', 'notion' ,'of' ,'a' ,'lambda' ,'function' ,'goes' ,'all' ,'the' ,'way' ,'back' ,'to' ,'the' ,'origin' ,'of', 'computer', 'science']

filtrado = list(filter(lambda x: True if len(x)>=4 else False,palabras))

print('Las palabras que permanecen después del filtrado son:',filtrado)
# Out:
# Las palabras que permanecen después del filtrado son: ['notion', 'lambda', 'function', 'goes', 'back', 'origin', 'computer', 'science']

# %% [markdown]
# 5. Use filter to determine the percentage of Fahrenheit temperatures in a list are within the range 32 to 80

# %% [markdown]
# ### Respuesta Ivette

# %%
np.random.seed(55555)
temperatures = np.random.uniform(25,110,30)

temperatura = list(filter(lambda x: 32 <= x <= 80, temperatures))

#ahora para saber el porcentaje de los que están en ese rango:
percentage = len(temperatura)/len(temperatures)
print("El porcentaje de temperaturas entre 32 y 80 Fahrenheit es:", percentage*100,"%")
# Out:
# El porcentaje de temperaturas entre 32 y 80 Fahrenheit es: 46.666666666666664 %

# %% [markdown]
# ### Respuesta Cristina

# %%
np.random.seed(55555)
temperatures = np.random.uniform(25,110,30)

grados = list(filter(lambda x: True if x>=32 and x<=80  else False,temperatures))
porcentaje = len(grados)/len(temperatures)
print('El porcentaje pedido es de:', round(porcentaje*100,2),'%')
# Out:
# El porcentaje pedido es de: 46.67 %

# %% [markdown]
# 6. Use reduce to find the lower left corner (minimum x and minimum y value) for a list of point locations
# > **Hint**: Explore the command `np.minimum.reduce` [link](https://docs.scipy.org/doc/numpy/reference/generated/numpy.ufunc.reduce.html)

# %% [markdown]
# ### Respuesta Ivette

# %%
np.random.seed(55555)
point_xy = np.random.randint(0,100,[30,2])
#print(point_xy)

# %%
resultado = reduce(lambda x,y: (min(point_xy[:,0]),min(point_xy[:,1])) ,point_xy)
print("The lower left corner is:",np.array(resultado))
# Out:
# The lower left corner is: [0 2]

# %% [markdown]
# ### Respuesta Cristina

# %%
print('Aplicando la función sugerida, el resultado es:', np.minimum.reduce(point_xy))
# Out:
# Aplicando la función sugerida, el resultado es: [0 2]

# %% [markdown]
# ### Ejercicio: Vectorizar distribución de poisson
# $$\textbf{Función de densidad de probabilidad}\\p(k)=\frac{\lambda^k e^{-\lambda}}{k!},\quad k\in \mathbb{N}$$

# %% [markdown]
# ### Respuesta Ivette

# %%
from itertools import cycle 
import matplotlib.pyplot as plt
import numpy as np
import scipy.special as sps
# %matplotlib inline
###
N=30
l=[1,3,5]
k=np.arange(N)
poisson= lambda k,l: (l**k*np.exp(-l))/(sps.factorial(k))
#Títulos de gráficas:
ax1.title.set_text("Densidad de distribución de probabilidad")
ax2.title.set_text("Distribución de probabilidad acumulada")
# Graficar para todo l una gráfica de p(k) usando subplots (como matrices)
#crear una matriz:
matriz= np.array([poisson(lamb,k) for lamb in l]) 
fig, (ax1,ax2) =plt.subplots(2,1, figsize=(8,8))
ax1.plot(k, matriz.T,'--',linewidth=3.0)#con traspuesta
#distribución acumulada:
ax2.plot(k, np.cumsum(matriz.T, axis=0),"--",linewidth=3)
# contruir el legend en latex para cada l
#legends:
ax1.legend([f'$\lambda={l}$' for l in l])
ax2.legend([f'$\lambda={l}$' for l in l])
plt.subplots_adjust(hspace=.4)
plt.show()

# %% [markdown]
# ### Respuesta Cristina

# %%
cycol = cycle('bgrcmk')

p = lambda k,l:(l**k*np.exp(-l))/sps.gamma(k)

# Como se haría de forma ineficiente
l= 1

def plotExponential(lamb, N, cycol):
    l= 1
    p = lambda k,l: (l**k * np.exp(-l)) / sps.factorial(k)
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10,10));

    ax1.title.set_text('Densidad de distrución de probabilidad')
    ax2.title.set_text('Distrución de probabilidad acumulada')

    for i in range(3):
        P = []
        c = next(cycol) 
            

        P = [p(k,l) for k in range(60) for cycol in range(3)]
        ax1.plot(P,'o',c=c,label='$\lambda$=%s' % l, markersize=2)        
        ax1.legend()

        ax2.plot(np.cumsum(P),'o',c=c,label='$\lambda$=%s' % l, markersize=3)
        ax2.legend()
        ax2.hlines(np.cumsum(P),range(len(P)),range(1,len(P)+1),color=c)
        l +=20
        
        

    plt.subplots_adjust(hspace=.4)
    return ax1,ax2

# %%
N = 30
l = [1, 3, 5]
k = np.arange(N)
plotExponential(l,N,cycol)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x11ea7830>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xf70a090>)
